# %% [markdown]
# # Assignment 1:developing a python script that can enable teachers to identify student engagement.

# %% [markdown]
# Step 1: Data Cleaning [½+1+½ =2 point]
# 1. Read the CSV file.
# 2. Remove the rows where ID is “ #N/A” or “2” (Instructor’s User ID)
# 3. Display the new “cleaned” Data

# %%
# !pip install pandas
import pandas as pd
# Out:
# WARNING: You are using pip version 20.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\prati\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in c:\users\prati\appdata\local\programs\python\python39\lib\site-packages (1.3.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\prati\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\prati\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\prati\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\prati\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
df=pd.read_csv("Asg1.csv")

# %%
df.head()
# Out:
#               Time   ID                               Event context Component  \
# 0  14/08/20, 19:53  2.0                                  Front page      Logs
# 1  14/08/20, 19:51  2.0                                  Front page    System
# 2  14/08/20, 19:50  2.0  Course: Introduction to Learning Analytics    System
# 3  14/08/20, 19:50  2.0                                      System    System
# 4  14/08/20, 15:42  2.0  Course: Introduction to Learning Analytics    System
#
#            Event name Origin
# 0   Log report viewed    web
# 1       Course viewed    web
# 2       Course viewed    web
# 3  User has logged in    web
# 4       Course viewed    web

# %%
df.dropna(subset = ["ID"], inplace=True)

# %%
df
# Out:
#                  Time   ID                               Event context  \
# 0     14/08/20, 19:53  2.0                                  Front page
# 1     14/08/20, 19:51  2.0                                  Front page
# 2     14/08/20, 19:50  2.0  Course: Introduction to Learning Analytics
# 3     14/08/20, 19:50  2.0                                      System
# 4     14/08/20, 15:42  2.0  Course: Introduction to Learning Analytics
# ...               ...  ...                                         ...
# 1397  23/07/20, 16:18  2.0  Course: Introduction to Learning Analytics
# 1398  23/07/20, 16:09  2.0                                  Front page
# 1399  23/07/20, 16:09  2.0                                  Front page
# 1400  23/07/20, 16:06  2.0                                  Front page
# 1401  23/07/20, 16:06  2.0                                      System
#
#      Component          Event name Origin
# 0         Logs   Log report viewed    web
# 1       System       Course viewed    web
# 2       System       Course viewed    web
# 3       System  User has logged in    web
# 4       System       Course viewed    web
# ...        ...                 ...    ...
# 1397    System      Course created    web
# 1398    System       Course viewed    web
# 1399    System       Course viewed    web
# 1400    System       Course viewed    web
# 1401    System  User has logged in    web
#
# [1386 rows x 6 columns]

# %%
# remove rows with ID=2 i.e instructors user ID
Cleaned_data = df[(df['ID'] != 2)]

# %%
Cleaned_data
# Out:
#                  Time   ID                               Event context  \
# 32     7/08/20, 01:20  6.0               Assignment: Stop motion video
# 33     7/08/20, 01:20  6.0               Assignment: Stop motion video
# 34     7/08/20, 01:20  6.0               Assignment: Stop motion video
# 36     7/08/20, 01:20  6.0               Assignment: Stop motion video
# 37     7/08/20, 01:20  6.0               Assignment: Stop motion video
# ...               ...  ...                                         ...
# 1224  25/07/20, 12:25  4.0  Course: Introduction to Learning Analytics
# 1225  25/07/20, 12:25  4.0  Course: Introduction to Learning Analytics
# 1226  25/07/20, 12:24  4.0  Course: Introduction to Learning Analytics
# 1227  25/07/20, 12:24  4.0                                      System
# 1248  24/07/20, 18:56  4.0                                      System
#
#              Component                                     Event name Origin
# 32          Assignment  The status of the submission has been viewed.    web
# 33          Assignment                           Course module viewed    web
# 34          Assignment               A submission has been submitted.    web
# 36    File submissions                            Submission created.    web
# 37    File submissions                      A file has been uploaded.    web
# ...                ...                                            ...    ...
# 1224            System                             Grade item updated    web
# 1225            System                           Badge listing viewed    web
# 1226            System                               User list viewed    web
# 1227            System                             User has logged in    web
# 1248            System                             User has logged in    web
#
# [667 rows x 6 columns]

# %% [markdown]
# Step 2: Action frequency. [4 point]
# (In this step create a data frame name “action_frequency” with the following information.)

# %% [markdown]
# ID    Total # of login  # of assignments done   # of discussion created  # of quizzes taken
# 3
# 4
# 6
#
#
# Note- The Event name for the above are-
#
# Login- User has logged in
# Assignments done -A submission has been submitted.
# Discussion created - Discussion created
# Quizzes taken - Quiz attempt submitted

# %%
df1=Cleaned_data.groupby(['ID','Event name'])['ID'].count()
df1
# Out:
# ID   Event name
# 3.0  A file has been uploaded.           2
#      A submission has been submitted.    2
#      Badge listing viewed                3
#      Choice answer added                 2
#      Comment created                     2
#                                         ..
# 6.0  Wiki history viewed                 5
#      Wiki page locks deleted             1
#      Wiki page map viewed                5
#      Wiki page updated                   1
#      Wiki page viewed                    6
# Name: ID, Length: 132, dtype: int64

# %%
df1=Cleaned_data.groupby(['Event name','ID'])['ID'].count()
df1
# Out:
# Event name                        ID
# A file has been uploaded.         3.0    2
#                                   4.0    2
#                                   6.0    3
# A submission has been submitted.  3.0    2
#                                   4.0    2
#                                         ..
# Wiki page updated                 4.0    1
#                                   6.0    1
# Wiki page viewed                  3.0    5
#                                   4.0    3
#                                   6.0    6
# Name: ID, Length: 132, dtype: int64

# %%
cd= Cleaned_data[(Cleaned_data['Event name'] == 'A submission has been submitted.')]
cd
# Out:
#                 Time   ID                          Event context   Component  \
# 34    7/08/20, 01:20  6.0          Assignment: Stop motion video  Assignment
# 47    7/08/20, 01:19  3.0  Assignment: you want everyone to read  Assignment
# 64    7/08/20, 01:18  6.0  Assignment: you want everyone to read  Assignment
# 81    7/08/20, 01:16  3.0          Assignment: Stop motion video  Assignment
# 578  28/07/20, 11:43  4.0  Assignment: you want everyone to read  Assignment
# 687  28/07/20, 09:00  4.0  Assignment: you want everyone to read  Assignment
# 931  26/07/20, 17:33  6.0  Assignment: you want everyone to read  Assignment
#
#                            Event name Origin
# 34   A submission has been submitted.    web
# 47   A submission has been submitted.    web
# 64   A submission has been submitted.    web
# 81   A submission has been submitted.    web
# 578  A submission has been submitted.    web
# 687  A submission has been submitted.    web
# 931  A submission has been submitted.    web

# %%
new=cd[['ID', 'Event name']]
new
# Out:
#       ID              Event name
# 700  4.0  Quiz attempt submitted
# 711  4.0  Quiz attempt submitted
# 876  6.0  Quiz attempt submitted
# 917  6.0  Quiz attempt submitted
# 953  6.0  Quiz attempt submitted
# 993  3.0  Quiz attempt submitted

# %%
df2=new.groupby(['ID']).count().reset_index()
df2
# Out:
#     ID  Event name
# 0  3.0           1
# 1  4.0           2
# 2  6.0           3

# %%
df2.columns =['ID', 'No.of Asst submitted']
df2
# Out:
#     ID  No.of Asst submitted
# 0  3.0                     1
# 1  4.0                     2
# 2  6.0                     3

# %%
cd= Cleaned_data[(Cleaned_data['Event name'] == 'User has logged in')]
new=cd[['ID', 'Event name']]
df3=new.groupby(['ID']).count().reset_index()
df3.columns =['ID', 'No.of logins']
df3
# Out:
#     ID  No.of logins
# 0  3.0             5
# 1  4.0             5
# 2  6.0             3

# %%
cd= Cleaned_data[(Cleaned_data['Event name'] == 'Discussion created')]
new=cd[['ID', 'Event name']]
df4=new.groupby(['ID']).count().reset_index()
df4.columns =['ID', 'No.of discussions']
df4
# Out:
#     ID  No.of discussions
# 0  4.0                  1

# %%
cd= Cleaned_data[(Cleaned_data['Event name'] == 'Quiz attempt submitted')]
new=cd[['ID', 'Event name']]
df5=new.groupby(['ID']).count().reset_index()
df5.columns =['ID', 'No.of quiz taken']
df5
# Out:
#     ID  No.of quiz taken
# 0  3.0                 1
# 1  4.0                 2
# 2  6.0                 3

# %%
a=df2.merge(df3, how='inner', on='ID')
a
# Out:
#     ID  No.of Asst submitted  No.of logins
# 0  3.0                     2             5
# 1  4.0                     2             5
# 2  6.0                     3             3

# %%
b=a.merge(df5, how='inner', on='ID')
b
# Out:
#     ID  No.of Asst submitted  No.of logins  No.of quiz taken
# 0  3.0                     2             5                 1
# 1  4.0                     2             5                 2
# 2  6.0                     3             3                 3

# %%
c=b.merge(df4, how='outer', on='ID')
c  #final dataframe
# Out:
#     ID  No.of Asst submitted  No.of logins  No.of quiz taken  \
# 0  3.0                     2             5                 1
# 1  4.0                     2             5                 2
# 2  6.0                     3             3                 3
#
#    No.of discussions
# 0                NaN
# 1                1.0
# 2                NaN

# %% [markdown]
# Step 3: Display the Data [ 1+1+2=4 point]
# 1. Plot a bar graph representing the total no. of logins by each user.
# 2. Plot a pie chart depicting the percentage of students submitting the assignment and not submitting it. (Since there are multiple assignments you can choose any one of them)
# 3. Represent the relationship between no of assignments submitted and no of ‘viewed’ actions using a scatter plot.

# %%
import matplotlib.pyplot

# %%
df3.plot.bar(x="ID", y="No.of logins", rot=70, title="Number of logins made by each user");

# %%
z=df2
z
# Out:
#     ID  No.of Asst submitted
# 0  3.0                     1
# 1  4.0                     2
# 2  6.0                     3

# %%
z['No.of Asst submitted'] = (z['No.of Asst submitted']/3) 
z
# Out:
#     ID  No.of Asst submitted
# 0  3.0              0.333333
# 1  4.0              0.666667
# 2  6.0              1.000000

# %%
z.plot.pie(y='No.of Asst submitted',labels =z['ID'])
# Out:
# <AxesSubplot:ylabel='No.of Asst submitted'>

# %%
cd1= Cleaned_data[(Cleaned_data['Event name'].str.contains('view') )]
cd1
# Out:
#                  Time   ID                               Event context  \
# 32     7/08/20, 01:20  6.0               Assignment: Stop motion video
# 33     7/08/20, 01:20  6.0               Assignment: Stop motion video
# 38     7/08/20, 01:20  6.0               Assignment: Stop motion video
# 44     7/08/20, 01:19  3.0       Assignment: you want everyone to read
# 45     7/08/20, 01:19  3.0       Assignment: you want everyone to read
# ...               ...  ...                                         ...
# 1211  25/07/20, 12:26  4.0                           File: Intro to LA
# 1222  25/07/20, 12:25  4.0  Course: Introduction to Learning Analytics
# 1223  25/07/20, 12:25  4.0  Course: Introduction to Learning Analytics
# 1225  25/07/20, 12:25  4.0  Course: Introduction to Learning Analytics
# 1226  25/07/20, 12:24  4.0  Course: Introduction to Learning Analytics
#
#         Component                                     Event name Origin
# 32     Assignment  The status of the submission has been viewed.    web
# 33     Assignment                           Course module viewed    web
# 38     Assignment                           Course module viewed    web
# 44     Assignment  The status of the submission has been viewed.    web
# 45     Assignment                                Feedback viewed    web
# ...           ...                                            ...    ...
# 1211         File                           Course module viewed    web
# 1222       System                                  Course viewed    web
# 1223  User report                       Grade user report viewed    web
# 1225       System                           Badge listing viewed    web
# 1226       System                               User list viewed    web
#
# [535 rows x 6 columns]

# %%
new1=cd1[['ID', 'Event name']]
df6=new1.groupby(['ID']).count().reset_index()
df6.columns =['ID', 'No.of views']
df6
# Out:
#     ID  No.of views
# 0  3.0          177
# 1  4.0          180
# 2  6.0          178

# %%
s=df2.merge(df6, how='inner', on='ID')
s
# Out:
#     ID  No.of Asst submitted  No.of views
# 0  3.0                     1          177
# 1  4.0                     2          180
# 2  6.0                     3          178

# %%
s.plot.scatter(x='No.of Asst submitted', y='No.of views')
# Out:
# <AxesSubplot:xlabel='No.of Asst submitted', ylabel='No.of views'>
